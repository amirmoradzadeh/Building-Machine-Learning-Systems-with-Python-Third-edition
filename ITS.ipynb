# %% [markdown]
# <a href="https://colab.research.google.com/github/amirmoradzadeh/Building-Machine-Learning-Systems-with-Python-Third-edition/blob/master/ITS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the necessary packages if you haven't already
# You can install these packages by running these commands in your terminal or command prompt:
# !pip install osmnx
# !pip install matplotlib

import osmnx as ox
import matplotlib.pyplot as plt

# Define the center coordinates and the radius (in meters) for Pomigliano
center_lat = 40.9101
center_lon = 14.3829
radius = 1000  # Adjust the radius as needed to cover your study area

# Retrieve the road network data from OpenStreetMap
G = ox.graph_from_point((center_lat, center_lon), dist=radius, network_type='all')

# Visualize the road network
ox.plot_graph(G)

# Display the plot
plt.show()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.2/107.2 kB 1.9 MB/s eta 0:00:00
# ...

# %%
# Install the necessary packages if you haven't already
# You can install these packages by running these commands in your terminal or command prompt:
# pip install osmnx
# pip install matplotlib
# pip install pandas

import osmnx as ox
import matplotlib.pyplot as plt
import pandas as pd

# Define the bounding box coordinates for Pomigliano
north = 40.937
south = 40.856
east = 14.413
west = 14.290

# Retrieve the road network data from OpenStreetMap
G = ox.graph_from_bbox(north, south, east, west, network_type='all')

# Construct the supply model based on the road network
supply_model = G.copy()

# Aggregate ISTAT census sections based on zoning requirements
# For simplicity, let's assume each node in the network represents a zone
zone_assignment = {node: 'Zone_' + str(index) for index, node in enumerate(supply_model.nodes)}

# Read the TomTom CSV file (assuming it's provided)
tomtom_data = pd.read_csv('/path/to/tomtom_data.csv')


# Validate the supply model and zoning results
if len(G.edges) != len(supply_model.edges):
    print("Warning: Some roads might not be included in the supply model.")

# Visualize the road network and supply model (optional)
fig, ax = ox.plot_graph(G, show=False, close=False)
ox.plot_graph(supply_model, ax=ax, edge_color='red', node_color='black', edge_linewidth=2)
plt.show()

# Document the project steps
with open('README.md', 'w') as file:
    file.write("""
    # Intelligent Transportation System Project

    This project aims to set up a macroscopic simulation model for the Pomigliano area.

    ## Data Acquisition

    - Retrieved road network data from OpenStreetMap.

    ## Data Preprocessing

    - Constructed the supply model based on the road network.

    ## Zoning

    - Aggregated ISTAT census sections to define zones.

    ## Prepare for TomTom Data

    - Readied the project for integrating TomTom data.

    ## Quality Assurance

    - Validated the supply model and zoning results.

    ## Documentation

    - Documented each step of the process for clarity and reproducibility.
    """)
# Out:
# <ipython-input-5-2794345d6d6c>:18: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   G = ox.graph_from_bbox(north, south, east, west, network_type='all')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-2794345d6d6c> in <cell line: 28>()
#      26
#      27 # Read the TomTom CSV file (assuming it's provided)
# ---> 28 tomtom_data = pd.read_csv('/path/to/tomtom_data.csv')
#      29
#      30
#
# ...
